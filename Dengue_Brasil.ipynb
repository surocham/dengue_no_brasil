# %% [markdown]
# <a href="https://colab.research.google.com/github/surocham/dengue_no_brasil/blob/main/Dengue_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dengue Brasil

# %% [markdown]
# ## Introdução

# %% [markdown]
# A dengue faz parte de um grupo de doenças denominadas arboviroses, que se caracterizam por serem causadas por vírus transmitidos por vetores artrópodes. No Brasil, o vetor da dengue é a fêmea do mosquito Aedes aegypti (significa "odioso do Egito"). Os vírus dengue (DENV) estão classificados cientificamente na família Flaviviridae e no gênero Orthoflavivirus. Até o momento são conhecidos quatro sorotipos – DENV-1, DENV-2, DENV-3 e DENV-4 –, que apresentam distintos materiais genéticos (genótipos) e linhagens.
#
# Mosquito se alimentando
# As evidências apontam que o mosquito tenha vindo nos navios que partiam da África com escravos. No Brasil, a primeira epidemia documentada clínica e laboratorialmente ocorreu em 1981-1982, em Boa Vista (RR), causada pelos sorotipos 1 e 4. Após quatro anos, em 1986, ocorreram epidemias atingindo o estado do Rio de Janeiro e algumas capitais da região Nordeste. Desde então, a dengue vem ocorrendo de forma continuada (endêmica), intercalando-se com a ocorrência de epidemias, geralmente associadas à introdução de novos sorotipos em áreas indenes (sem transmissão) e/ou alteração do sorotipo predominante, acompanhando a expansão do mosquito vetor.
#
# Aspectos como a urbanização, o crescimento desordenado da população, o saneamento básico deficitário e os fatores climáticos mantêm as condições favoráveis para a presença do vetor, com reflexos na dinâmica de transmissão desses arbovírus. A dengue possui padrão sazonal, com aumento do número de casos e o risco para epidemias, principalmente entre os meses de outubro de um ano a maio do ano seguinte.

# %% [markdown]
# ## Sinais e sintomas
#
# A dengue é uma doença febril aguda, sistêmica, dinâmica, debilitante e autolimitada. A maioria dos doentes se recupera, porém, parte deles podem progredir para formas graves, inclusive virem a óbito. A quase totalidade dos óbitos por dengue é evitável e depende, na maioria das vezes, da qualidade da assistência prestada e organização da rede de serviços de saúde.

# %% [markdown]
# ### Link Ministério da Saúde
#
# Base de Dados da MS: http://tabnet.datasus.gov.br/cgi/deftohtm.exe?sinannet/cnv/denguebr.def
#
# Documentos importantes: https://www.gov.br/saude/pt-br/assuntos/saude-de-a-a-z/d/dengue

# %%
# manipulação dos dados
import pandas as pd
import numpy as np

# visualização dos dados
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_dengue = pd.read_excel('Base de Dados Dengue.xlsx')

# %%
# a função head() pega os 5 primeiros da tabela contando do zero,
# se for um número especifico é só colocar entre os ()

df_dengue.head()
# Out:
#                municipio  uf data_infeccoes  qtd_infeccoes
# 0  ALTA FLORESTA D'OESTE  RO     2013-01-01             34
# 1  ALTA FLORESTA D'OESTE  RO     2013-02-01             44
# 2  ALTA FLORESTA D'OESTE  RO     2013-03-01             15
# 3  ALTA FLORESTA D'OESTE  RO     2013-04-01              4
# 4  ALTA FLORESTA D'OESTE  RO     2013-05-01              3

# %%
# Para visualizar os últimos, basta usar o tail()
df_dengue.tail()
# Out:
#        municipio  uf data_infeccoes  qtd_infeccoes
# 728767  BRASILIA  DF     2023-08-01            939
# 728768  BRASILIA  DF     2023-09-01            843
# 728769  BRASILIA  DF     2023-10-01            686
# 728770  BRASILIA  DF     2023-11-01           1300
# 728771  BRASILIA  DF     2023-12-01           5603

# %% [markdown]
# ## Explorando o dataset

# %%
# Qual o formato do banco de dados?
df_dengue.shape
# Out:
# (728772, 4)

# %%
# Para deixar os dados bem documentados podemos utilizar o print
print(f'Tamanho do nosso Dataset: {df_dengue.shape}')
# Out:
# Tamanho do nosso Dataset: (728772, 4)

# %%
# Para saber os tipos das colunas
df_dengue.dtypes
# Out:
# municipio                 object
# uf                        object
# data_infeccoes    datetime64[ns]
# qtd_infeccoes              int64
# dtype: object

# %% [markdown]
# Existe valores nulos?

# %%
# Identifica dados nulos
df_dengue.isnull()
# Out:
#         municipio     uf  data_infeccoes  qtd_infeccoes
# 0           False  False           False          False
# 1           False  False           False          False
# 2           False  False           False          False
# 3           False  False           False          False
# 4           False  False           False          False
# ...           ...    ...             ...            ...
# 728767      False  False           False          False
# 728768      False  False           False          False
# 728769      False  False           False          False
# 728770      False  False           False          False
# 728771      False  False           False          False
#
# [728772 rows x 4 columns]

# %%
# Para mostrar a quantidade de valores nulos por toda a tabela
df_dengue.isnull().sum()
# Out:
# municipio         0
# uf                0
# data_infeccoes    0
# qtd_infeccoes     0
# dtype: int64

# %%
# Quantos valores nulos?
df_dengue.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# Documentando

print(f'Quantidade de dados nulos: {df_dengue.isnull().sum().sum()}')
# Out:
# Quantidade de dados nulos: 0

# %%
df_dengue.isnull()
# Out:
#         municipio     uf  data_infeccoes  qtd_infeccoes
# 0           False  False           False          False
# 1           False  False           False          False
# 2           False  False           False          False
# 3           False  False           False          False
# 4           False  False           False          False
# ...           ...    ...             ...            ...
# 728767      False  False           False          False
# 728768      False  False           False          False
# 728769      False  False           False          False
# 728770      False  False           False          False
# 728771      False  False           False          False
#
# [728772 rows x 4 columns]

# %%
df_dengue.isnull().sum()
# Out:
# municipio         0
# uf                0
# data_infeccoes    0
# qtd_infeccoes     0
# dtype: int64

# %%
df_dengue.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Informação sobre a base

# %%
# Pequeno resumo
df_dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728772 entries, 0 to 728771
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   municipio       728772 non-null  object
#  1   uf              728772 non-null  object
#  2   data_infeccoes  728772 non-null  datetime64[ns]
#  3   qtd_infeccoes   728772 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 22.2+ MB

# %% [markdown]
# Verificar os valores unicos

# %%
df_dengue.nunique()
# Out:
# municipio         5243
# uf                  27
# data_infeccoes     132
# qtd_infeccoes     1157
# dtype: int64

# %% [markdown]
# Temos todos os municipios como foco da dengue? Não, temos apenas 5.243

# %% [markdown]
# Precisamos calcular a quantidade de pessoas que pegaram dengue por municipio e por ano.

# %%
# Criar uma coluna de ano
df_dengue ['ano'] = df_dengue['data_infeccoes'].dt.year

# %%
# Conferindo se deu certo
df_dengue.head()
# Out:
#                municipio  uf data_infeccoes  qtd_infeccoes   ano
# 0  ALTA FLORESTA D'OESTE  RO     2013-01-01             34  2013
# 1  ALTA FLORESTA D'OESTE  RO     2013-02-01             44  2013
# 2  ALTA FLORESTA D'OESTE  RO     2013-03-01             15  2013
# 3  ALTA FLORESTA D'OESTE  RO     2013-04-01              4  2013
# 4  ALTA FLORESTA D'OESTE  RO     2013-05-01              3  2013

# %%
# Colocando por municipio e unidade federativa

# o groupby vai pegar todo os valores que se repetem e agrupa por caracteristica.

# o reset_index serve para não misturar os números

infeccoes_municipio = df_dengue.groupby(['municipio','ano','uf'])['qtd_infeccoes'].sum().reset_index()

# %%
infeccoes_municipio.head()
# Out:
#          municipio   ano  uf  qtd_infeccoes
# 0  ABADIA DE GOIAS  2013  GO             52
# 1  ABADIA DE GOIAS  2014  GO             20
# 2  ABADIA DE GOIAS  2015  GO             40
# 3  ABADIA DE GOIAS  2016  GO             14
# 4  ABADIA DE GOIAS  2017  GO             15

# %%
infeccoes_municipio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60731 entries, 0 to 60730
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   municipio      60731 non-null  object
#  1   ano            60731 non-null  int32
#  2   uf             60731 non-null  object
#  3   qtd_infeccoes  60731 non-null  int64
# dtypes: int32(1), int64(1), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# Agrupar por Estado e Ano

# %%
infeccoes_estado = df_dengue.groupby(['ano','uf'])['qtd_infeccoes'].sum().reset_index()

# %%
infeccoes_estado
# Out:
#       ano  uf  qtd_infeccoes
# 0    2013  AC           1663
# 1    2013  AL            704
# 2    2013  AM           4327
# 3    2013  AP            546
# 4    2013  BA          13417
# ..    ...  ..            ...
# 292  2023  RS          27389
# 293  2023  SC          77954
# 294  2023  SE           1749
# 295  2023  SP         198774
# 296  2023  TO           1232
#
# [297 rows x 3 columns]

# %%
infeccoes_estado.head()
# Out:
#     ano  uf  qtd_infeccoes
# 0  2013  AC           1663
# 1  2013  AL            704
# 2  2013  AM           4327
# 3  2013  AP            546
# 4  2013  BA          13417

# %% [markdown]
# Estatistica Descritiva

# %%
infeccoes_estado.describe()
# Out:
#                ano  qtd_infeccoes
# count   297.000000     297.000000
# mean   2018.000000   12872.474747
# std       3.167615   31630.107741
# min    2013.000000       0.000000
# 25%    2015.000000     780.000000
# 50%    2018.000000    2229.000000
# 75%    2021.000000   10098.000000
# max    2023.000000  286000.000000

# %%
infeccoes_estado.shape
# Out:
# (297, 3)

# %% [markdown]
# Interpretação da estatistica descritiva utilizando o gráfico do Boxplot

# %%
# Criando o gráfico de Boxplot, comparando a quantidade de infecções por ano

plt.figure(figsize = (10,6))
sns.boxplot(data = infeccoes_estado, x = 'ano', y = 'qtd_infeccoes', palette = 'viridis')

# Personalizar o gráfico

plt.title('Quantidade de Infecções por Ano', fontsize = 14)
plt.xlabel('Ano', fontsize = 12)
plt.ylabel('Quantidade de Infecções', fontsize = 12)
plt.grid(axis = 'y', linestyle = '--', alpha = 0.7)
plt.show()
# Out:
# /tmp/ipython-input-1249713816.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = infeccoes_estado, x = 'ano', y = 'qtd_infeccoes', palette = 'viridis')

# %% [markdown]
# ### Interpretação do gráfico
#
# O gráfico boxplot apresenta a distribuição das infecções por ano, evidenciando uma grande variabilidade na quantidade de casos confirmados. A presença de outliers demonstra períodos em que houve surtos de grande escala, o que reforça a necessidade de um monitoramento continuo. Os picos de infecções coincidem com eventos climáticos favoráveis à proliferação do mosquito como temporadas de chuvas intensas.

# %% [markdown]
# Filtro Ano de 2023

# %%
# Filtrar os dados para o ano de 2023

infeccoes_estado_2023 = infeccoes_estado[infeccoes_estado['ano'] == 2023]
infeccoes_estado_2023
# Out:
#       ano  uf  qtd_infeccoes
# 270  2023  AC           1781
# 271  2023  AL            473
# 272  2023  AM           3263
# 273  2023  AP            742
# 274  2023  BA          13249
# 275  2023  CE           7437
# 276  2023  DF          23710
# 277  2023  ES              0
# 278  2023  GO          21682
# 279  2023  MA           2428
# 280  2023  MG         106923
# 281  2023  MS          21098
# 282  2023  MT          19356
# 283  2023  PA           2607
# 284  2023  PB            746
# 285  2023  PE            680
# 286  2023  PI            431
# 287  2023  PR          48328
# 288  2023  RJ          27905
# 289  2023  RN            355
# 290  2023  RO           7904
# 291  2023  RR            182
# 292  2023  RS          27389
# 293  2023  SC          77954
# 294  2023  SE           1749
# 295  2023  SP         198774
# 296  2023  TO           1232

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data = infeccoes_estado_2023, y = 'qtd_infeccoes')
plt.title('Boxplot de infecções por Estado / 2023')
plt.ylabel('Quantidade de informações')
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# %%
fig = px.box(infeccoes_estado_2023, x = 'uf', y = 'qtd_infeccoes', color = 'uf', title = 'Boxplot de Infecções por Estado /2023')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9a51abef-1d34-4b1b-960e-6dc7edb46c49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a51abef-1d34-4b1b-960e-6dc7edb46c49")) {                    Plotly.newPlot(                        "9a51abef-1d34-4b1b-960e-6dc7edb46c49",                        [{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AC","marker":{"color":"#636efa"},"name":"AC","notched":false,"offsetgroup":"AC","orientation":"v","showlegend":true,"x":["AC"],"x0":" ","xaxis":"x","y":[1781],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AL","marker":{"color":"#EF553B"},"name":"AL","notched":false,"offsetgroup":"AL","orientation":"v","showlegend":true,"x":["AL"],"x0":" ","xaxis":"x","y":[473],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AM","marker":{"color":"#00cc96"},"name":"AM","notched":false,"offsetgroup":"AM","orientation":"v","showlegend":true,"x":["AM"],"x0":" ","xaxis":"x","y":[3263],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AP","marker":{"color":"#ab63fa"},"name":"AP","notched":false,"offsetgroup":"AP","orientation":"v","showlegend":true,"x":["AP"],"x0":" ","xaxis":"x","y":[742],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BA","marker":{"color":"#FFA15A"},"name":"BA","notched":false,"offsetgroup":"BA","orientation":"v","showlegend":true,"x":["BA"],"x0":" ","xaxis":"x","y":[13249],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CE","marker":{"color":"#19d3f3"},"name":"CE","notched":false,"offsetgroup":"CE","orientation":"v","showlegend":true,"x":["CE"],"x0":" ","xaxis":"x","y":[7437],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DF","marker":{"color":"#FF6692"},"name":"DF","notched":false,"offsetgroup":"DF","orientation":"v","showlegend":true,"x":["DF"],"x0":" ","xaxis":"x","y":[23710],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ES","marker":{"color":"#B6E880"},"name":"ES","notched":false,"offsetgroup":"ES","orientation":"v","showlegend":true,"x":["ES"],"x0":" ","xaxis":"x","y":[0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GO","marker":{"color":"#FF97FF"},"name":"GO","notched":false,"offsetgroup":"GO","orientation":"v","showlegend":true,"x":["GO"],"x0":" ","xaxis":"x","y":[21682],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MA","marker":{"color":"#FECB52"},"name":"MA","notched":false,"offsetgroup":"MA","orientation":"v","showlegend":true,"x":["MA"],"x0":" ","xaxis":"x","y":[2428],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eqtd_infeccoes=%{y}\u003cextra\u003e\u003c\u002fextra\u0 ...

# %% [markdown]
# Comparação entre os estados

# %%
plt.figure(figsize = (12,6 ))
sns.barplot(data = infeccoes_estado_2023, x ='uf', y='qtd_infeccoes', palette = 'viridis')

# Personalizar o gráfico

plt.title('Quantidade de Infecções por Estado em 2023', fontsize = 14)
plt.xlabel('Estados', fontsize = 12)
plt.grid(axis = 'y', linestyle= '--', alpha = 0.7)


# Exibir o gráfico
plt.show()
# Out:
# /tmp/ipython-input-2091674170.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Ordenar os dados do maior para o menor número de infecções

# %%
infeccoes_2023 = infeccoes_estado_2023.sort_values(by = 'qtd_infeccoes', ascending=False)

# %%
infeccoes_2023
# Out:
#       ano  uf  qtd_infeccoes
# 295  2023  SP         198774
# 280  2023  MG         106923
# 293  2023  SC          77954
# 287  2023  PR          48328
# 288  2023  RJ          27905
# 292  2023  RS          27389
# 276  2023  DF          23710
# 278  2023  GO          21682
# 281  2023  MS          21098
# 282  2023  MT          19356
# 274  2023  BA          13249
# 290  2023  RO           7904
# 275  2023  CE           7437
# 272  2023  AM           3263
# 283  2023  PA           2607
# 279  2023  MA           2428
# 270  2023  AC           1781
# 294  2023  SE           1749
# 296  2023  TO           1232
# 284  2023  PB            746
# 273  2023  AP            742
# 285  2023  PE            680
# 271  2023  AL            473
# 286  2023  PI            431
# 289  2023  RN            355
# 291  2023  RR            182
# 277  2023  ES              0

# %%
# Criar um gráfico de barras comparando os estados de forma ordenada

plt.figure(figsize = (12,6))
sns.barplot(data = infeccoes_2023, x= 'uf', y= 'qtd_infeccoes', palette='viridis')

# Personalizar o gráfico

plt.title('Quantidade de Infecções por Estado em 2023', fontsize = 14)
plt.xlabel('Estado', fontsize = 12)
plt.ylabel('Quantidade de infecções', fontsize=12)
plt.xticks(rotation= 45)
plt.grid(axis= 'y', linestyle= '-', alpha= 0.7)
# Out:
# /tmp/ipython-input-4113264155.py:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ### Interpretação
# Este gráfico mostra a quantidade de infecções confirmadas em cada estado brasileiro no ano de 2023. São Paulo, Minas Gerais e Santa Catarina lideram em número absoluto de casos, o que pode estar relacionado à alta densidade populacional e condições climáticas favoráveis ao mosquito transmissor.

# %% [markdown]
# Gráfico de Tendências

# %%
# Criar o gráfico de tendencias
plt.figure(figsize= (12,6))
sns.regplot(data= infeccoes_estado, x= 'ano', y= 'qtd_infeccoes', scatter_kws={"s": 15}, line_kws={"color":"red"})

# Personalizando o gráfico
plt.title('Tendências de Infecções ao Longo dos Anos', fontsize= 14)
plt.xlabel('Ano', fontsize= 12)
plt.ylabel('Quantidade de infecções', fontsize= 12)
plt.grid(True)
